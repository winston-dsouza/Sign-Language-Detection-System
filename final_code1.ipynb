# %% [markdown]
# <a href="https://colab.research.google.com/github/winston-dsouza/Sign-Language-Detection-System/blob/master/final_code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Run the below code snippets in CPU backend mode

# %%
s = '''!wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-00?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f5bf823ed2769e4cadb035ed13b1a19ba67c92f9b91b280c26bde082eae66b7e"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-01?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=bcc4e6e86f42371993c94825608cea8ea181a2e8301c89c187fa083f81c6d721"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-02?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=00989e3076ddb50b2595ebf1a50b78dcb4ca6d0bef7314d8b672369163d29a9e"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-03?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=26bec5475d2fcd7fccb86efd631d0eb95064724fda45d700c984dc83803ea8ed"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-04?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=33ba1964e93c3b83e530a90476df79b52163336fd8200ffaf09ca3a87d76591a"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-05?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=691769edd6d499e61658ab237dc56c048531e0b1a02ccb33b6e772e37b16b73e"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-06?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=1e9043f55ffad7b0ffcdd0dd6e7ea613946ff4cac576e34834f85bd15d04b177"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-07?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=032c3920c3270a5c1709f368696be34fb10f6c7124779d2e269b1dda9d5512b4"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-08?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=b0f82a14d9079175e56d6266a751aef58d0b91d28ab9a4678a12c9e814c77805"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-09?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=5e41f4f56adeb4928b4853a974ffdad76516cf96b20c292bd5696975447c3c58"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-10?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=40bde84d76d99b7b41061e95ed32c0d80543e343ab3629c1fc4b78c5ddc202fb"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-11?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=3fffbca52dc73d9c3dc647403034b96d7fe4930f695a86cda4ce638c4065c3ac"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-12?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=471eafe5eb959c3db522d106d3c0d5b1d9ac14235401e5fd662adf8ff371a114"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-13?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f0f3e83aaa0df6766ae42e463838391099741ac5094178e75aacb4c1fd346749"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-14?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f5024a31db90bf71c12c34b16e87fa46bbae2ba6e2f81558fbcaff9fd797e74e"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-15?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=41eba6b3a20af7f6f7a3671e7003536ae82ed6a782a534b250d0a7909ed24163"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-16?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=a6c6f8b022a448097fd84f3208e97865625cd485b32fa501da845b06f8930325"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-17?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=915cdba967dd7a2043f3f5c06d0970b06add3b1e6b34d2edecd3a879b10f72b9"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-18?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=5fbce7de4c2fca33f3096b218941d7313183e8db6bd19d28ce0416c97ae047df"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-19?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=e28876f3c3ffd693edabe0203536e2ecdbe90b2b115d74e21643892a154796e5"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-20?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=ee07e1fac7ca7c7f767bdd6ddbf7beff5358913b24ac0268f2ca2cc0902279e3"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-21?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=6e22513efaf33e8d8942abd7933fcd768ded6c1a279c0568a96fc958cf7d005f"
VM245:5 !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-22?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f77bc8d900899b8c29ff0de4aa10d05eedf17663ff6f405321c8126868540b10"
'''
try:
    while(s.index("VM") != -1):
        index = s.index("VM")
        s = s[:index] + s[index + 8:]
except:
    print(s)

# %%
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-00?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f5bf823ed2769e4cadb035ed13b1a19ba67c92f9b91b280c26bde082eae66b7e"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-01?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=bcc4e6e86f42371993c94825608cea8ea181a2e8301c89c187fa083f81c6d721"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-02?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=00989e3076ddb50b2595ebf1a50b78dcb4ca6d0bef7314d8b672369163d29a9e"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-03?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=26bec5475d2fcd7fccb86efd631d0eb95064724fda45d700c984dc83803ea8ed"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-04?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=33ba1964e93c3b83e530a90476df79b52163336fd8200ffaf09ca3a87d76591a"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-05?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=691769edd6d499e61658ab237dc56c048531e0b1a02ccb33b6e772e37b16b73e"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-06?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=1e9043f55ffad7b0ffcdd0dd6e7ea613946ff4cac576e34834f85bd15d04b177"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-07?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=032c3920c3270a5c1709f368696be34fb10f6c7124779d2e269b1dda9d5512b4"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-08?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=b0f82a14d9079175e56d6266a751aef58d0b91d28ab9a4678a12c9e814c77805"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-09?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=5e41f4f56adeb4928b4853a974ffdad76516cf96b20c292bd5696975447c3c58"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-10?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=40bde84d76d99b7b41061e95ed32c0d80543e343ab3629c1fc4b78c5ddc202fb"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-11?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=3fffbca52dc73d9c3dc647403034b96d7fe4930f695a86cda4ce638c4065c3ac"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-12?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=471eafe5eb959c3db522d106d3c0d5b1d9ac14235401e5fd662adf8ff371a114"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-13?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f0f3e83aaa0df6766ae42e463838391099741ac5094178e75aacb4c1fd346749"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-14?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f5024a31db90bf71c12c34b16e87fa46bbae2ba6e2f81558fbcaff9fd797e74e"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-15?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=41eba6b3a20af7f6f7a3671e7003536ae82ed6a782a534b250d0a7909ed24163"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-16?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=a6c6f8b022a448097fd84f3208e97865625cd485b32fa501da845b06f8930325"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-17?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=915cdba967dd7a2043f3f5c06d0970b06add3b1e6b34d2edecd3a879b10f72b9"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-18?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=5fbce7de4c2fca33f3096b218941d7313183e8db6bd19d28ce0416c97ae047df"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-19?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=e28876f3c3ffd693edabe0203536e2ecdbe90b2b115d74e21643892a154796e5"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-20?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=ee07e1fac7ca7c7f767bdd6ddbf7beff5358913b24ac0268f2ca2cc0902279e3"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-21?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=6e22513efaf33e8d8942abd7933fcd768ded6c1a279c0568a96fc958cf7d005f"
# !wget "https://20bn-data-packages.s3.eu-west-1.amazonaws.com/jester/v1/20bn-jester-v1-22?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ2PXKOHYMBEGX4UA%2F20200613%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20200613T132259Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f77bc8d900899b8c29ff0de4aa10d05eedf17663ff6f405321c8126868540b10"
# !wget https://20bn.com/dataset-release/jester/v1/train
# !wget https://20bn.com/dataset-release/jester/v1/validation
# !wget https://20bn.com/dataset-release/jester/v1/test
# !wget https://20bn.com/dataset-release/jester/v1/labels

# %%
# !rm 20bn-jester-v1-*

# %%
cat 20bn-jester-v1-* | tar zx

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import keras
import os
import math
import pandas as pd
import matplotlib.image as img
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import numpy as np
import shutil
import csv
# Out:
# Using TensorFlow backend.

# %%
path = "/content/20bn-jester-v1"
dirs = os.listdir(path)

# %%
targets = pd.read_csv('/content/jester-v1-train.csv', header=None,sep = ";", names=['', 'values'], index_col=0)['values'].to_dict()

# %%
print(len(targets))
# Out:
# 118562

# %%
results = []
for k,v in targets.items():
    if v=='Thumb Up':
        for directory in dirs:
                if k == int(directory):
                    results.append(k)

# %%
print(len(results))
# Out:
# 4373

# %%
os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/training-data/'

# %%
for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

# %%
dict1 = {}
for val in results:
  dict1.update( {val : 'Thumb Up'} )

# %%
print(len(dict1))
# Out:
# 8651

# %%
results = []
for k,v in targets.items():
    if v=='No gesture':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/training-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict1.update( {val : 'No gesture'} )

# %%
results = []
for k,v in targets.items():
    if v=='Swiping Right':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/training-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict1.update( {val : 'Swiping Right'} )

# %%
results = []
for k,v in targets.items():
    if v=='Sliding Two Fingers Left':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/training-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict1.update( {val : 'Sliding Two Fingers Left'} )

# %%
results = []
for k,v in targets.items():
    if v=='Rolling Hand Forward':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/training-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict1.update( {val : 'Rolling Hand Forward'} )

# %%
results = []
for k,v in targets.items():
    if v=='Zooming Out With Two Fingers':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/training-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict1.update( {val : 'Zooming Out With Two Fingers'} )

# %%
print(len(dict1))
# Out:
# 25482

# %%
targets_validation = pd.read_csv('/content/jester-v1-validation.csv', header=None,sep = ";", names=['', 'values'], index_col=0)['values'].to_dict()
results = []

# %%
for k,v in targets_validation.items():
    if v=='Thumb Up':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/validation-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

dict2 = {}
for val in results:
  dict2.update( {val : 'Thumb Up'} )

# %%
len(dict2)
# Out:
# 539

# %%
results = []
for k,v in targets_validation.items():
    if v=='No gesture':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/validation-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict2.update( {val : 'No gesture'} )

# %%
results = []
for k,v in targets_validation.items():
    if v=='Swiping Right':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/validation-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict2.update( {val : 'Swiping Right'} )

# %%
results = []
for k,v in targets_validation.items():
    if v=='Sliding Two Fingers Left':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/validation-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict2.update( {val : 'Sliding Two Fingers Left'} )

# %%
results = []
for k,v in targets_validation.items():
    if v=='Rolling Hand Forward':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/validation-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict2.update( {val : 'Rolling Hand Forward'} )

# %%
results = []
for k,v in targets_validation.items():
    if v=='Zooming Out With Two Fingers':
        for directory in dirs:
                if k == int(directory):
                    results.append(k) 

os.chdir('/content/20bn-jester-v1/')
path = '/content/20bn-jester-v1/'
path1= '/content/validation-data/'

for val in results:
    for directory in dirs:
            if val==int(directory):
                if os.path.isdir(path+directory):
                    shutil.copytree(directory,path1+str(val))

for val in results:
  dict2.update( {val : 'Zooming Out With Two Fingers'} )

# %%
print("Number of training data:")
print(len(dict1))

print("Number of validation data:")
print(len(dict2))
# Out:
# Number of training data:
# 25482
# Number of validation data:
# 3128

# %%
dict1

# %%
with open('/content/training.csv', 'w') as f:
    for key in dict1.keys():
        f.write("%d,%s\n"%(key,dict1[key]))

with open('/content/validation.csv', 'w') as f:
    for key in dict2.keys():
        f.write("%d,%s\n"%(key,dict2[key]))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !zip -r /content/training-data1.zip  /content/training-data
#!zip -r /content/validation-data1.zip  /content/validation-data

# %%
# !mv /content/training-data1.zip /content/drive/My\ Drive/Colab\ Notebooks/SLD/
#!mv /content/validation-data1.zip /content/drive/My\ Drive/Colab\ Notebooks/SLD/

# %%
# !mv /content/training.csv /content/drive/My\ Drive/Colab\ Notebooks/SLD
# !mv /content/validation.csv /content/drive/My\ Drive/Colab\ Notebooks/SLD

# %% [markdown]
# SWITCH TO GPU MODE AFTER THIS

# %%
# !unzip /content/drive/My\ Drive/Colab\ Notebooks/SLD/training-data1.zip
# !unzip /content/drive/My\ Drive/Colab\ Notebooks/SLD/validation-data1.zip
# !cp /content/drive/My\ Drive/Colab\ Notebooks/SLD/training.csv /content/
# !cp /content/drive/My\ Drive/Colab\ Notebooks/SLD/validation.csv /content/

# %%
targets = pd.read_csv('/content/training.csv', header=None,sep = ",", names=['', 'values'], index_col=0)['values'].to_dict()
targets_validation = pd.read_csv('/content/validation.csv', header=None,sep = ",", names=['', 'values'], index_col=0)['values'].to_dict()

# %%
class Conv3DModel(tf.keras.Model):
  def __init__(self):
    super(Conv3DModel, self).__init__()
    # Convolutions
    self.conv1 = tf.compat.v2.keras.layers.Conv3D(32, (3, 3, 3), activation='relu', name="conv1", data_format='channels_last')
    self.pool1 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2), data_format='channels_last')
    self.conv2 = tf.compat.v2.keras.layers.Conv3D(64, (3, 3, 3), activation='relu', name="conv1", data_format='channels_last')
    self.pool2 = tf.keras.layers.MaxPool3D(pool_size=(2, 2,2), data_format='channels_last')
   
    # LSTM & Flatten
    self.convLSTM =tf.keras.layers.ConvLSTM2D(40, (3, 3))
    self.flatten =  tf.keras.layers.Flatten(name="flatten")

    # Dense layers
    self.d1 = tf.keras.layers.Dense(128, activation='relu', name="d1")
    self.out = tf.keras.layers.Dense(6, activation='softmax', name="output")
    
  def call(self, x):
    x = self.conv1(x)
    x = self.pool1(x)
    x = self.conv2(x)
    x = self.pool2(x)
    x = self.convLSTM(x)
    #x = self.pool2(x)
    #x = self.conv3(x)
    #x = self.pool3(x)
    x = self.flatten(x)
    x = self.d1(x)
    return self.out(x)



model = Conv3DModel()
# choose the loss and optimizer methods
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics = ['accuracy'])

# %%
path = "/content/content/training-data/"
path_cv = "/content/content/validation-data"

dirs = os.listdir(path)
dirs_cv = os.listdir(path_cv)
dirs1,dirs_cv1 = os.listdir(path),os.listdir(path_cv)
for i in range(0, len(dirs)): 
    dirs1[i]=int(dirs[i])
for j in range(0, len(dirs_cv)): 
    dirs_cv1[j]=int(dirs_cv[j])

# %%
n = [0] * (max(list(targets.keys()))+10) #Training List maintained to ensure no directory is considered more than once
m = [0] * (max(list(targets_validation.keys()))+10)
print(len(dirs))
print(len(dirs_cv))
print(dirs)
print(dirs_cv)
print(len(n))
print(len(m))
# Out:
# 25482
# 3128
# ...

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
# Resize frames
def resize_frame(frame):
    frame = img.imread(frame)
    frame = cv2.resize(frame, (64, 64))
    return frame

# %%
hm_frames = 30 
def get_unify_frames(path):
    offset = 0
    # pick frames
    frames = os.listdir(path)
    frames_count = len(frames)
    # unify number of frames 
    if hm_frames > frames_count:
        # duplicate last frame if video is shorter than necessary
        frames += [frames[-1]] * (hm_frames - frames_count)
    elif hm_frames < frames_count:
        # If there are more frames, then sample starting offset
        #diff = (frames_count - hm_frames)
        #offset = diff-1 
        frames = frames[0:hm_frames]
    return frames

# %%
targets_name = ["Thumb Up","No gesture","Swiping Right","Sliding Two Fingers Left","Rolling Hand Forward","Zooming Out With Two Fingers"]
# !rm -r /content/train
# !rm -r /content/validation1
# Out:
# rm: cannot remove '/content/train': No such file or directory
# rm: cannot remove '/content/validation1': No such file or directory

# %%
for iteration in range(10):
  #------------------------------------------------------PROCESSING AND PREPARING THE TRAINING DATA-----------------------------------------------------#

  counter_train = 0
  results_train = []
  batch_dict = {}
  results_train = []
  path = "/content/content/training-data/"
  dirs = os.listdir(path)
  for k,v in targets.items():
    if counter_train != 2500  and n[k]==0:
      if v=='No gesture' or 'Swiping Right' or 'Sliding Two Fingers Left' or 'Thumb Up' or 'Rolling Hand Forward' or 'Zooming Out With Two Fingers':
        for directory in dirs:
          if k == int(directory):
            batch_dict.update({k:v})
            n[k]=1
            results_train.append(k)
            counter_train += 1  
  # print(len(results_train))
  # print(batch_dict)
  # !rm -r /content/train

  import shutil
  os.chdir('/content/content/training-data/')
  path = '/content/content/training-data/'
  path1= '/content/train/'
  for val in results_train:
      for directory in dirs:
              if val==int(directory):
                  if os.path.isdir(path+directory):
                      shutil.copytree(directory,path1+str(val))

  # Adjust training data
  dirs = os.listdir(path1)
  counter_training = 0 # number of training
  training_targets = [] # training targets 
  new_frames = [] # training data after resize & unify
  for directory in dirs:
      new_frame = [] # one training
      # Frames in each folder
      frames = get_unify_frames(path1+directory)
      if len(frames) == hm_frames: # just to be sure
          for frame in frames:
              frame = resize_frame(path1+directory+'/'+frame)
              new_frame.append(rgb2gray(frame))
              if len(new_frame) == 15: # partition each training on two trainings.
                  new_frames.append(new_frame) # append each partition to training data
                  training_targets.append(targets_name.index(batch_dict[int(directory)]))
                  counter_training +=1
                  new_frame = []


  #show data
  fig = plt.figure()
  for i in range(2,4):
      for num,frame in enumerate(new_frames[i][0:18]):
          y = fig.add_subplot(4,5,num+1)
          y.imshow(frame, cmap='gray')
      fig = plt.figure()
  plt.show()


  # convert training data to np float32
  training_data = np.array(new_frames[0:counter_training], dtype=np.float32)

  #print shape
  print(training_data.shape)



  # Normalisation: training
  print('old mean', training_data.mean())
  scaler = StandardScaler()
  scaled_images  = scaler.fit_transform(training_data.reshape(-1, 15*64*64))
  print('new mean', scaled_images.mean())
  scaled_images  = scaled_images.reshape(-1, 15, 64, 64, 1)
  print(scaled_images.shape)




  #------------------------------------------------------------------------------------------------------------------------------------------------------#




  #------------------------------------------------------PROCESSING AND PREPARING THE VALIDATION DATA-----------------------------------------------------#


  counter_validate = 0
  results_validation = []
  batch_dict_validation = {}
  results_validation = []
  path_cv = "/content/content/validation-data/"
  dirs_cv = os.listdir(path_cv)
  for k,v in targets_validation.items():
    if counter_validate != 310   and m[k]==0:
      if v=='No gesture' or 'Swiping Right' or 'Sliding Two Fingers Left' or 'Thumb Up' or 'Rolling Hand Forward' or 'Zooming Out With Two Fingers':
        for directory in dirs_cv:
          if k == int(directory):
            batch_dict_validation.update({k:v})
            m[k]=1
            results_validation.append(k)
            counter_validate += 1  
  print(len(results_validation))
  # !rm -r /content/validation1
  import shutil
  os.chdir('/content/content/validation-data/')
  path = '/content/content/validation-data/'
  path1_cv= '/content/validation1/'
  for val in results_validation:
      for directory in dirs_cv:
              if val==int(directory):
                  if os.path.isdir(path+directory):
                      shutil.copytree(directory,path1_cv+str(val))


  # Adjust validation data
  dirs_cv = os.listdir(path1_cv)
  counter_validation = 0
  cv_targets = []
  new_frames_cv = []
  for directory in dirs_cv:
      new_frame = []
      # Frames in each folder
      frames = get_unify_frames(path1_cv+directory)
      if len(frames)==hm_frames:
          for frame in frames:
              frame = resize_frame(path1_cv+directory+'/'+frame)
              new_frame.append(rgb2gray(frame))
              if len(new_frame) == 15:
                  new_frames_cv.append(new_frame)
                  cv_targets.append(targets_name.index(batch_dict_validation[int(directory)]))
                  counter_validation +=1
                  new_frame = []


  # convert validation data to np float32
  cv_data = np.array(new_frames_cv[0:counter_validation], dtype=np.float32)




  #print shape
  print(cv_data.shape)



  # Normalisation: validation
  print('old mean', cv_data.mean())
  scaler = StandardScaler()
  scaled_images_cv  = scaler.fit_transform(cv_data.reshape(-1, 15*64*64))
  print('new mean',scaled_images_cv.mean())
  scaled_images_cv  = scaled_images_cv.reshape(-1, 15, 64, 64, 1)
  print(scaled_images_cv.shape)






  #------------------------------------------------------------------------------------------------------------------------------------------------------#
  #TRANSFER DATA TO NUMPY ARRAYS
  x_train = np.array(scaled_images)
  y_train = np.array(training_targets)
  x_val = np.array(scaled_images_cv)
  y_val = np.array(cv_targets)
  print(x_train.shape)
  print(y_train.shape)
  print(x_val.shape)
  print(y_val.shape)



  # Run the training 
  history = model.fit(x_train, y_train,
                      validation_data=(x_val, y_val),
                      batch_size=32,
                      epochs=2,verbose=1)
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()


  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()


  if iteration==9:
    print('Finished')
# Out:
# rm: cannot remove '/content/train': No such file or directory
# (5000, 15, 64, 64)
# old mean 110.05953
# new mean 1.3373891e-08
# (5000, 15, 64, 64, 1)
# 310
# rm: cannot remove '/content/validation1': No such file or directory
# (620, 15, 64, 64)
# old mean 109.45891
# new mean -7.896013e-09
# (620, 15, 64, 64, 1)
# (5000, 15, 64, 64, 1)
# (5000,)
# (620, 15, 64, 64, 1)
# (620,)
# Epoch 1/2
# 157/157 [==============================] - 8s 51ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/2
# 157/157 [==============================] - 8s 48ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# (5000, 15, 64, 64)
# old mean 109.72342
# new mean -1.5717347e-08
# (5000, 15, 64, 64, 1)
# 310
# (620, 15, 64, 64)
# old mean 107.35207
# new mean -2.261131e-08
# (620, 15, 64, 64, 1)
# (5000, 15, 64, 64, 1)
# (5000,)
# (620, 15, 64, 64, 1)
# (620,)
# Epoch 1/2
# ...

# %%
model.save_weights('/content/WEIGHTS_6GESTURES', save_format='tf')
